# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
fig, ax = plt.subplots()


def f(x, y):
    return np.sin(x) + np.cos(y)

x = np.linspace(0, 2 * np.pi, 120)
y = np.linspace(0, 2 * np.pi, 100).reshape(-1, 1)

# ims is a list of lists, each row is a list of artists to draw in the
# current frame; here we are just animating one artist, the image, in
# each frame
ims = []
for i in range(60):
    x += np.pi / 15.
    y += np.pi / 20.
    im = ax.imshow(f(x, y), animated=True)
    if i == 0:
        ax.imshow(f(x, y))  # show an initial one first
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=1000)

# To save the animation, use e.g.
# pip install ffmpeg-python
ani.save("movie.mp4")
#
# or
#
# writer = animation.FFMpegWriter(
#     fps=15, metadata=dict(artist='Me'), bitrate=1800)
# ani.save("movie.mp4", writer=writer)

plt.show()
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/matplotlib/animation.py:234, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     233 try:
# --> 234     yield self
#     235 finally:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/animation.py:1089, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1087 for anim, d in zip(all_anim, data):
#    1088     # TODO: See if turning off blit is really necessary
# -> 1089     anim._draw_next_frame(d, blit=False)
#    1090     if progress_callback is not None:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/animation.py:1125, in Animation._draw_next_frame(self, framedata, blit)
#    1124 self._draw_frame(framedata)
# -> 1125 self._post_draw(framedata, blit)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/animation.py:1150, in Animation._post_draw(self, framedata, blit)
#    1149 else:
# -> 1150     self._fig.canvas.draw_idle()
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/backend_bases.py:2060, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2059 with self._idle_draw_cntx():
# -> 2060     self.draw(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:436, in FigureCanvasAgg.draw(self)
#     433 with RendererAgg.lock, \
#     434      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435       else nullcontext()):
# --> 436     self.figure.draw(self.renderer)
#     437     # A GUI class may be need to update a window using this draw, so
#     438     # don't forget to call the superclass.
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/figure.py:2845, in Figure.draw(self, renderer)
#    2844 self.patch.draw(renderer)
# -> 2845 mimage._draw_list_compositing_images(
#    2846     renderer, self, artists, self.suppressComposite)
#    2848 for sfig in self.subfigs:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py:3091, in _AxesBase.draw(self, renderer)
#    3089     renderer.stop_rasterizing()
# -> 3091 mimage._draw_list_compositing_images(
#    3092     renderer, self, artists, self.figure.suppressComposite)
#    3094 renderer.close_group('axes')
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/image.py:646, in _ImageBase.draw(self, renderer, *args, **kwargs)
#     645 else:
# --> 646     im, l, b, trans = self.make_image(
#     647         renderer, renderer.get_image_magnification())
#     648     if im is not None:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/image.py:956, in AxesImage.make_image(self, renderer, magnification, unsampled)
#     954 clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     955         else self.figure.bbox)
# --> 956 return self._make_image(self._A, bbox, transformed_bbox, clip,
#     957                         magnification, unsampled=unsampled)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/image.py:516, in _ImageBase._make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     514 # we always have to interpolate the mask to account for
#     515 # non-affine transformations
# --> 516 out_alpha = _resample(self, mask, out_shape, t, resample=True)
#     517 # done with the mask now, delete from namespace to be sure!
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/image.py:193, in _resample(image_obj, data, out_shape, transform, resample, alpha)
#     192     resample = image_obj.get_resample()
# --> 193 _image.resample(data, out, transform,
#     194                 _interpd_[interpolation],
#     195                 resample,
#     196                 alpha,
#     197                 image_obj.get_filternorm(),
#     198                 image_obj.get_filterrad())
#     199 return out
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/PIL/Image.py:2298, in Image.save(self, fp, format, **params)
#    2297 try:
# -> 2298     format = EXTENSION[ext]
#    2299 except KeyError as e:
#
# KeyError: '.mp4'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In [2], line 27
#      22 ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
#      23                                 repeat_delay=1000)
#      25 # To save the animation, use e.g.
#      26 # pip install ffmpeg-python
# ---> 27 ani.save("movie.mp4")
#      28 #
#      29 # or
#      30 #
#      31 # writer = animation.FFMpegWriter(
#      32 #     fps=15, metadata=dict(artist='Me'), bitrate=1800)
#      33 # ani.save("movie.mp4", writer=writer)
#      35 plt.show()
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/animation.py:1093, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1091         progress_callback(frame_number, total_frames)
#    1092         frame_number += 1
# -> 1093 writer.grab_frame(**savefig_kwargs)
#
# File /usr/lib/python3.8/contextlib.py:131, in _GeneratorContextManager.__exit__(self, type, value, traceback)
#     129     value = type()
#     130 try:
# --> 131     self.gen.throw(type, value, traceback)
#     132 except StopIteration as exc:
#     133     # Suppress StopIteration *unless* it's the same exception that
#     134     # was passed to throw().  This prevents a StopIteration
#     135     # raised inside the "with" statement from being suppressed.
#     136     return exc is not value
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/animation.py:236, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     234     yield self
#     235 finally:
# --> 236     self.finish()
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/animation.py:512, in PillowWriter.finish(self)
#     511 def finish(self):
# --> 512     self._frames[0].save(
#     513         self.outfile, save_all=True, append_images=self._frames[1:],
#     514         duration=int(1000 / self.fps), loop=0)
#
# File ~/.local/lib/python3.8/site-packages/PIL/Image.py:2300, in Image.save(self, fp, format, **params)
#    2298         format = EXTENSION[ext]
#    2299     except KeyError as e:
# -> 2300         raise ValueError(f"unknown file extension: {ext}") from e
#    2302 if format.upper() not in SAVE:
#    2303     init()
#
# ValueError: unknown file extension: .mp4
