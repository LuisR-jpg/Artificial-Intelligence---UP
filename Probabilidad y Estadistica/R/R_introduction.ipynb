# %%
#1. Operaciones aritméticas
#2 + 2
#2. Variables
#a = 3*(5 + 4)
#print(a) #Imprimir
b = 3:40
#print(b)
d <- 15 #Igual a =
#d
#3. Vectores
vu <- 1:5
vd = c(1, 1, 2, 3, 5) #C es concatenar
vSuma = vu + vd
#vSuma
#4. Matrices
matrizA = matrix(c(1, 1, 2, 3, 5, 8), nrow=2, byrow=TRUE)
#cat("matrizA: ")
#matrizA
matrizB = matrix(c(8, 5, 3, 2, 1, 1), nrow=2, byrow=FALSE)
#matrizB
matrizC = matrizA + matrizB
#matrizC

#5. Seleccionar secciones de una matriz
renglon = matrizA[1,]
#renglon
columna = matrizA[,2]
#columna
elemento = matrizA[2, 3]
#elemento
dosRenglones = matrizA[1:2, 2:3]
#dosRenglones

#6. Graficar Funciones
x = seq(0, 2*pi, length=50)
y = sin(x)
#Plot de funcion
#plot(x, y, type="l")
#Plot de color
#plot(x, y, type="l", col="green")
#Plot con grueso
#plot(x, y, type="l", col="blue", lwd=2)
#Plot Punteado
#plot(x, y, type="l", col="blue", lwd=2, lty=2)
#Linea 
#abline(h=0, v=1, col="red")

x = seq(0, 2*pi, length=50)
y1 = sin(x)
y2 = cos(x)
plot(x, y1, type="l", col="purple", lwd=2, xlab="Este es el eje X")
lines(x, y2, col="pink", lwd=2)
abline(h=0, v=0, col="red")
# Out:
# plot without title

# %%
  graf_bastones = function(x, p){
    plot(x, p, pch=16, col = "slateblue") #pch es tipo de caracter
    for(linea in 1:length(x)){
      lines(c(x[linea], x[linea]), c(0, p[linea]), col="slateblue")
    }
  }
  x = 1:6
  p = rep(1/6, times = 6)
  graf_bastones(x, p)
# Out:
# plot without title
