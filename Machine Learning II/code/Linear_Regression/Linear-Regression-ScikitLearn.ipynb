# %% [markdown]
# # Simple Linear Regression (Hours of study)
#
# The goal of this project was to build a linear regression model from the ground up using scikitlearn.

# %%
# %matplotlib inline

#Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Import the data
#
# Here, we're using a dataset with two columns containing the amount of hours studied and the test scores students achieved, respectively.

# %%
#Mount Drive
#from google.colab import drive
#drive.mount('/content/drive')

#Data path 
dataset_path = '/content/drive/MyDrive/Colab Notebooks/data.csv'

# %%
#Dataset:
dataset = pd.read_csv(dataset_path)

#Extract columns
x = dataset.iloc[:, :-1].values
x = x.tolist()
y = dataset.iloc[:, 1].values
y = y.tolist()

#Plot the dataset
plt.scatter(x,y)
plt.xlabel('Hours of study')
plt.ylabel('Test scores')
plt.title('Dataset')
plt.show()

# %% [markdown]
# ### Training the Algorithm

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2)

# %%
from sklearn import datasets, linear_model
regressor = linear_model.LinearRegression()
regressor.fit(X_train,Y_train)
#print(regressor.intercept_)
#print(regressor.coef_)
# Out:
# LinearRegression()

# %%
Y_pred = regressor.predict(X_test)

# %%
df = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})
df
# Out:
#         Actual  Predicted
# 0    65.101712  66.952957
# 1   115.244153  91.885354
# 2    71.139728  81.209503
# 3    95.229366  92.718567
# 4    45.570589  51.000629
# 5    71.546632  70.960893
# 6    83.878565  96.188833
# 7    69.847604  74.615162
# 8    62.562382  89.907576
# 9    80.166275  58.348639
# 10   86.520538  91.207569
# 11   75.392870  85.375531
# 12   90.123572  69.282992
# 13   82.892504  67.201888
# 14   85.668203  79.340469
# 15   66.588144  68.217432
# 16   44.862491  60.287262
# 17   73.434642  75.831448
# 18   61.424710  66.101080
# 19   62.124571  56.078747

# %%
plt.scatter(x, y)
plt.plot(X_test, Y_pred, color='red', linewidth=3)
plt.xlabel('Hours of study')
plt.ylabel('Test scores')
plt.title('Line of best fit')
plt.show()

# %% [markdown]
# # Simple Linear Regression (California housing)
#
# The goal of this project was to build a linear regression model from the ground up using scikitlearn.

# %%
#Imports
import numpy as np
from sklearn import datasets, linear_model
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import the data

# %%
#Mount Drive
#from google.colab import drive
#drive.mount('/content/drive')

#Dataset
dataset = datasets.load_boston()
print("Dataset size:", dataset.data.shape)
# Out:
# Dataset size: (506, 13)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#
#   warnings.warn(msg, category=FutureWarning)

# %%
#Extract columns

#Select column "RM" (Average number of rooms per dwelling)
#print('Columns:',dataset.feature_names)
X = dataset.data[:, np.newaxis, 5]
Y = dataset.target

# %%
#Plot the dataset
plt.scatter(X,Y)
plt.xlabel('Number of rooms')
plt.ylabel('Mean value')
plt.show()

# %% [markdown]
# ### Training the Algorithm

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
regressor = linear_model.LinearRegression()
regressor.fit(X_train,Y_train)
#print(regressor.intercept_)
#print(regressor.coef_)
# Out:
# LinearRegression()

# %%
Y_pred = regressor.predict(X_test)

# %%
df = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})
df
# Out:
#      Actual  Predicted
# 0      12.7  17.421992
# 1      27.9  16.486270
# 2      14.1  24.658245
# 3      17.5  20.104396
# 4      17.1  24.025519
# ..      ...        ...
# 97     39.8  35.708681
# 98     42.8  40.111032
# 99     16.8  20.220248
# 100    29.6  21.343115
# 101    28.6  26.021727
#
# [102 rows x 2 columns]

# %%
plt.scatter(X, Y)
plt.plot(X_test, Y_pred, color='red', linewidth=3)
plt.title('Line of best fit')
plt.xlabel('Number of rooms')
plt.ylabel('Mean value')
plt.show()
