# %% [markdown]
# # Logistic regresion:

# %% [markdown]
# Links of additional good resources:
#
#   Github of "Python Data Science Handbook": https://github.com/jakevdp/PythonDataScienceHandbook
#
#   Colab version of "Python Data Science Handbook": https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/Index.ipynb
#
#   A Colab related to Scikit-Learn: https://colab.research.google.com/github/rugantio/MachineLearningCourse/blob/master/class06_Scikit-Learn.ipynb#scrollTo=9AsDtWyfJJau

# %% [markdown]
# ## A Simple Example: the Iris Dataset
#
# As an example of a simple dataset, we're going to take a look at the
# iris data stored by scikit-learn.
# The data consists of measurements of three different species of irises.
# There are three species of iris in the dataset, which we can picture here:

# %%
from IPython.core.display import Image, display
display(Image('http://mirlab.org/jang/books/dcpr/image/Iris-setosa-10_1.jpg', width=200, height=200))
print ("Iris Setosa\n")

display(Image('http://mirlab.org/jang/books/dcpr/image/Iris-versicolor-21_1.jpg', width=200, height=200))
print ("Iris Versicolor\n")

display(Image('http://mirlab.org/jang/books/dcpr/image/Iris-virginica-3_1.jpg', width=200, height=200))
print ("Iris Virginica")
# Out:
# /tmp/ipykernel_5100/972192858.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import Image, display
# Iris Setosa
# Iris Versicolor
# Iris Virginica

# %% [markdown]
# ### Loading the Iris Data with Scikit-Learn
#
# Scikit-learn has a very straightforward set of data on these iris species.  The data consist of
# the following:
#
# - Features in the Iris dataset:
#
#   1. sepal length in cm
#   2. sepal width in cm
#   3. petal length in cm
#   4. petal width in cm
#
#
# - Target classes to predict:
#
#   1. Iris Setosa
#   2. Iris Versicolour
#   3. Iris Virginica
#
# ``scikit-learn`` embeds a copy of the iris CSV file along with a helper function to load it into numpy arrays:

# %%
import numpy as np
from sklearn import datasets
iris = datasets.load_iris()

X = iris["data"][:, 3:] # We are just takin 1 feature from the datset: petal width
y = (iris["target"] == 2).astype(np.int) # 1 if Iris-Virginica, else 0
X.shape #We have 150 registries on the dataset
# Out:
# /tmp/ipykernel_5100/1059705561.py:6: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = (iris["target"] == 2).astype(np.int) # 1 if Iris-Virginica, else 0
# (150, 1)

# %% [markdown]
# ##Visualization of two features from Iris dataset

# %%
import matplotlib.pyplot as plt

x_index = 2
y_index = 3

# this formatter will label the colorbar with the correct target names
formatter = plt.FuncFormatter(lambda i, *args: iris.target_names[int(i)])

plt.scatter(iris.data[:, x_index], iris.data[:, y_index],
            c=iris.target)
plt.colorbar(ticks=[0, 1, 2], format=formatter)
plt.xlabel(iris.feature_names[x_index])
plt.ylabel(iris.feature_names[y_index]);

# %% [markdown]
# ## Split Dataset into Train/Test

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .10, random_state = 42)
X_train.shape
# Out:
# (135, 1)

# %% [markdown]
# ## Definitions and the class to predict, calculate the loss and train the logistic model

# %%
def _sigmoid(z):
    return 1.0/(1 + np.exp(-(z)))

def _loss(y, y_hat):
    loss = -np.mean(y * (np.log(y_hat)) + (1 - y) * np.log(1-y_hat))
    return loss


class LogisticReg:
    
    def __init__(self, lr = 0.01, epochs = 100):
        self.lr = lr
        self.epochs = epochs
        self.weights = None
        self.bias = None
    
    # training step
    def fit(self, X, y, debug = False):
        
        # M is the size of samples
        # N is the size of features
        m, n = X.shape
        
        self.weights = np.zeros((n, 1))
        self.bias = 0
        
        # for safety
        y = y.reshape(m, 1)
        
        # save the history, for debug information
        losses = list()
        b_list = list()
        w_list = list()
        
        # gradient loop
        for epoch in range(self.epochs):
            
            # calculate prediction
            y_hat = _sigmoid(np.dot(X, self.weights) + self.bias)
            
            # calculate and save current loss
            loss = _loss(y, y_hat)
            losses.append(loss)
            
            # calculate gradient
            dw = (1/m) * np.dot(X.T, (y_hat - y))
            db = (1/m) * np.sum((y_hat - y))
            
            # update parameters
            self.weights = self.weights - self.lr * dw            
            self.bias = self.bias - self.lr * db
            
            # save the parameters
            w_list.append(self.weights)
            b_list.append(self.bias)
            
            # print
            if (debug and epoch % 100 == 0):
                print(f"epoch: {epoch}, loss: {np.round(loss, 4)}")
            
        return self.weights, self.bias, losses, b_list, w_list    

    # the probability predicted
    def prob_predict(self, X):
        preds = _sigmoid(np.dot(X, self.weights) + self.bias)
        return np.array(preds)

    # the class predicted
    def predict(self, X):
        preds = self.prob_predict(X)
        pred_class = [1 if i > 0.5 else 0 for i in preds]
        return np.array(pred_class)

# %%
model = LogisticReg(lr = 0.01, epochs = 50000)
w, b, loss, b_list, w_list = model.fit(X_train, y_train, debug = True)
w, b
# Out:
# epoch: 0, loss: 0.6931
# epoch: 100, loss: 0.6627
# epoch: 200, loss: 0.6351
# epoch: 300, loss: 0.6102
# epoch: 400, loss: 0.5876
# epoch: 500, loss: 0.567
# epoch: 600, loss: 0.5484
# epoch: 700, loss: 0.5313
# epoch: 800, loss: 0.5158
# epoch: 900, loss: 0.5015
# epoch: 1000, loss: 0.4884
# epoch: 1100, loss: 0.4763
# epoch: 1200, loss: 0.4651
# epoch: 1300, loss: 0.4548
# epoch: 1400, loss: 0.4452
# epoch: 1500, loss: 0.4363
# epoch: 1600, loss: 0.428
# epoch: 1700, loss: 0.4202
# epoch: 1800, loss: 0.4129
# epoch: 1900, loss: 0.4061
# epoch: 2000, loss: 0.3997
# epoch: 2100, loss: 0.3936
# epoch: 2200, loss: 0.3879
# epoch: 2300, loss: 0.3825
# epoch: 2400, loss: 0.3774
# epoch: 2500, loss: 0.3725
# epoch: 2600, loss: 0.3679
# epoch: 2700, loss: 0.3635
# epoch: 2800, loss: 0.3593
# epoch: 2900, loss: 0.3553
# epoch: 3000, loss: 0.3515
# epoch: 3100, loss: 0.3478
# epoch: 3200, loss: 0.3443
# epoch: 3300, loss: 0.341
# epoch: 3400, loss: 0.3377
# epoch: 3500, loss: 0.3347
# epoch: 3600, loss: 0.3317
# epoch: 3700, loss: 0.3288
# epoch: 3800, loss: 0.326
# epoch: 3900, loss: 0.3234
# epoch: 4000, loss: 0.3208
# epoch: 4100, loss: 0.3183
# epoch: 4200, loss: 0.3159
# epoch: 4300, loss: 0.3136
# epoch: 4400, loss: 0.3113
# epoch: 4500, loss: 0.3092
# epoch: 4600, loss: 0.307
# epoch: 4700, loss: 0.305
# epoch: 4800, loss: 0.303
# epoch: 4900, loss: 0.3011
# epoch: 5000, loss: 0.2992
# epoch: 5100, loss: 0.2974
# epoch: 5200, loss: 0.2956
# epoch: 5300, loss: 0.2938
# epoch: 5400, loss: 0.2922
# epoch: 5500, loss: 0.2905
# epoch: 5600, loss: 0.2889
# epoch: 5700, loss: 0.2873
# epoch: 5800, loss: 0.2858
# epoch: 5900, loss: 0.2843
# epoch: 6000, loss: 0.2829
# epoch: 6100, loss: 0.2814
# epoch: 6200, loss: 0.2801
# epoch: 6300, loss: 0.2787
# epoch: 6400, loss: 0.2774
# epoch: 6500, loss: 0.2761
# epoch: 6600, loss: 0.2748
# epoch: 6700, loss: 0.2736
# epoch: 6800, loss: 0.2723
# epoch: 6900, loss: 0.2711
# epoch: 7000, loss: 0.27
# epoch: 7100, loss: 0.2688
# epoch: 7200, loss: 0.2677
# epoch: 7300, loss: 0.2666
# epoch: 7400, loss: 0.2655
# epoch: 7500, loss: 0.2644
# epoch: 7600, loss: 0.2634
# epoch: 7700, loss: 0.2624
# epoch: 7800, loss: 0.2614
# epoch: 7900, loss: 0.2604
# epoch: 8000, loss: 0.2594
# epoch: 8100, loss: 0.2584
# epoch: 8200, loss: 0.2575
# epoch: 8300, loss: 0.2566
# epoch: 8400, loss: 0.2557
# epoch: 8500, loss: 0.2548
# epoch: 8600, loss: 0.2539
# epoch: 8700, loss: 0.253
# epoch: 8800, loss: 0.2522
# epoch: 8900, loss: 0.2513
# epoch: 9000, loss: 0.2505
# epoch: 9100, loss: 0.2497
# epoch: 9200, loss: 0.2489
# epoch: 9300, loss: 0.2481
# epoch: 9400, loss: 0.2473
# epoch: 9500, loss: 0.2466
# epoch: 9600, loss: 0.2458
# epoch: 9700, loss: 0.2451
# epoch: 9800, loss: 0.2443
# epoch: 9900, loss: 0.2436
# epoch: 10000, loss: 0.2429
# epoch: 10100, loss: 0.2422
# epoch: 10200, loss: 0.2415
# epoch: 10300, loss: 0.2408
# epoch: 10400, loss: 0.2401
# epoch: 10500, loss: 0.2395
# epoch: 10600, loss: 0.2388
# epoch: 10700, loss: 0.2382
# epoch: 10800, loss: 0.2375
# epoch: 10900, loss: 0.2369
# epoch: 11000, loss: 0.2363
# epoch: 11100, loss: 0.2356
# epoch: 11200, loss: 0.235
# epoch: 11300, loss: 0.2344
# epoch: 11400, loss: 0.2338
# epoch: 11500, loss: 0.2333
# epoch: 11600, loss: 0.2327
# epoch: 11700, loss: 0.2321
# epoch: 11800, loss: 0.2315
# epoch: 11900, loss: 0.231
# epoch: 12000, loss: 0.2304
# epoch: 12100, loss: 0.2299
# epoch: 12200, loss: 0.2293
# epoch: 12300, loss: 0.2288
# epoch: 12400, loss: 0.2283
# epoch: 12500, loss: 0.2277
# epoch: 12600, loss: 0.2272
# epoch: 12700, loss: 0.2267
# epoch: 12800, loss: 0.2262
# epoch: 12900, loss: 0.2257
# epoch: 13000, loss: 0.2252
# epoch: 13100, loss: 0.2247
# epoch: 13200, loss: 0.2242
# epoch: 13300, loss: 0.2237
# epoch: 13400, loss: 0.2233
# epoch: 13500, loss: 0.2228
# epoch: 13600, loss: 0.2223
# epoch: 13700, loss: 0.2219
# epoch: 13800, loss: 0.2214
# epoch: 13900, loss: 0.2209
# epoch: 14000, loss: 0.2205
# epoch: 14100, loss: 0.2201
# epoch: 14200, loss: 0.2196
# epoch: 14300, loss: 0.2192
# epoch: 14400, loss: 0.2187
# epoch: 14500, loss: 0.2183
# epoch: 14600, loss: 0.2179
# epoch: 14700, loss: 0.2175
# epoch: 14800, loss: 0.2171
# epoch: 14900, loss: 0.2166
# epoch: 15000, loss: 0.2162
# epoch: 15100, loss: 0.2158
# epoch: 15200, loss: 0.2154
# epoch: 15300, loss: 0.215
# epoch: 15400, loss: 0.2146
# epoch: 15500, loss: 0.2142
# epoch: 15600, loss: 0.2139
# epoch: 15700, loss: 0.2135
# epoch: 15800, loss: 0.2131
# epoch: 15900, loss: 0.2127
# epoch: 16000, loss: 0.2123
# epoch: 16100, loss: 0.212
# epoch: 16200, loss: 0.2116
# epoch: 16300, loss: 0.2112
# epoch: 16400, loss: 0.2109
# epoch: 16500, loss: 0.2105
# epoch: 16600, loss: 0.2102
# epoch: 16700, loss: 0.2098
# epoch: 16800, loss: 0.2095
# epoch: 16900, loss: 0.2091
# epoch: 17000, loss: 0.2088
# epoch: 17100, loss: 0.2084
# epoch: 17200, loss: 0.2081
# epoch: 17300, loss: 0.2078
# epoch: 17400, loss: 0.2074
# epoch: 17500, loss: 0.2071
# epoch: 17600, loss: 0.2068
# epoch: 17700, loss: 0.2065
# epoch: 17800, loss: 0.2061
# epoch: 17900, loss: 0.2058
# epoch: 18000, loss: 0.2055
# epoch: 18100, loss: 0.2052
# epoch: 18200, loss: 0.2049
# epoch: 18300, loss: 0.2046
# epoch: 18400, loss: 0.2042
# epoch: 18500, loss: 0.2039
# epoch: 18600, loss: 0.2036
# epoch: 18700, loss: 0.2033
# epoch: 18800, loss: 0.203
# epoch: 18900, loss: 0.2027
# epoch: 19000, loss: 0.2024
# epoch: 19100, loss: 0.2022
# epoch: 19200, loss: 0.2019
# epoch: 19300, loss: 0.2016
# epoch: 19400, loss: 0.2013
# epoch: 19500, loss: 0.201
# epoch: 19600, loss: 0.2007
# epoch: 19700, loss: 0.2004
# epoch: 19800, loss: 0.2002
# epoch: 19900, loss: 0.1999
# epoch: 20000, loss: 0.1996
# epoch: 20100, loss: 0.1993
# epoch: 20200, loss: 0.1991
# epoch: 20300, loss: 0.1988
# epoch: 20400, loss: 0.1985
# epoch: 20500, loss: 0.1983
# epoch: 20600, loss: 0.198
# epoch: 20700, loss: 0.1977
# epoch: 20800, loss: 0.1975
# epoch: 20900, loss: 0.1972
# epoch: 21000, loss: 0.197
# epoch: 21100, loss: 0.1967
# epoch: 21200, loss: 0.1965
# epoch: 21300, loss: 0.1962
# epoch: 21400, loss: 0.196
# epoch: 21500, loss: 0.1957
# epoch: 21600, loss: 0.1955
# epoch: 21700, loss: 0.1952
# epoch: 21800, loss: 0.195
# epoch: 21900, loss: 0.1947
# epoch: 22000, loss: 0.1945
# epoch: 22100, loss: 0.1943
# epoch: 22200, loss: 0.194
# epoch: 22300, loss: 0.1938
# epoch: 22400, loss: 0.1936
# epoch: 22500, loss: 0.1933
# epoch: 22600, loss: 0.1931
# epoch: 22700, loss: 0.1929
# epoch: 22800, loss: 0.1926
# epoch: 22900, loss: 0.1924
# epoch: 23000, loss: 0.1922
# epoch: 23100, loss: 0.192
# epoch: 23200, loss: 0.1917
# epoch: 23300, loss: 0.1915
# epoch: 23400, loss: 0.1913
# epoch: 23500, loss: 0.1911
# epoch: 23600, loss: 0.1909
# epoch: 23700, loss: 0.1906
# epoch: 23800, loss: 0.1904
# epoch: 23900, loss: 0.1902
# epoch: 24000, loss: 0.19
# epoch: 24100, loss: 0.1898
# epoch: 24200, loss: 0.1896
# epoch: 24300, loss: 0.1894
# epoch: 24400, loss: 0.1892
# epoch: 24500, loss: 0.189
# epoch: 24600, loss: 0.1888
# epoch: 24700, loss: 0.1885
# epoch: 24800, loss: 0.1883
# epoch: 24900, loss: 0.1881
# epoch: 25000, loss: 0.1879
# epoch: 25100, loss: 0.1877
# epoch: 25200, loss: 0.1875
# epoch: 25300, loss: 0.1873
# epoch: 25400, loss: 0.1872
# epoch: 25500, loss: 0.187
# epoch: 25600, loss: 0.1868
# epoch: 25700, loss: 0.1866
# epoch: 25800, loss: 0.1864
# epoch: 25900, loss: 0.1862
# epoch: 26000, loss: 0.186
# epoch: 26100, loss: 0.1858
# epoch: 26200, loss: 0.1856
# epoch: 26300, loss: 0.1854
# epoch: 26400, loss: 0.1853
# epoch: 26500, loss: 0.1851
# epoch: 26600, loss: 0.1849
# epoch: 26700, loss: 0.1847
# epoch: 26800, loss: 0.1845
# epoch: 26900, loss: 0.1843
# epoch: 27000, loss: 0.1842
# epoch: 27100, loss: 0.184
# epoch: 27200, loss: 0.1838
# epoch: 27300, loss: 0.1836
# epoch: 27400, loss: 0.1834
# epoch: 27500, loss: 0.1833
# epoch: 27600, loss: 0.1831
# epoch: 27700, loss: 0.1829
# epoch: 27800, loss: 0.1828
# epoch: 27900, loss: 0.1826
# epoch: 28000, loss: 0.1824
# epoch: 28100, loss: 0.1822
# epoch: 28200, loss: 0.1821
# epoch: 28300, loss: 0.1819
# epoch: 28400, loss: 0.1817
# epoch: 28500, loss: 0.1816
# epoch: 28600, loss: 0.1814
# epoch: 28700, loss: 0.1812
# epoch: 28800, loss: 0.1811
# epoch: 28900, loss: 0.1809
# epoch: 29000, loss: 0.1808
# epoch: 29100, loss: 0.1806
# epoch: 29200, loss: 0.1804
# epoch: 29300, loss: 0.1803
# epoch: 29400, loss: 0.1801
# epoch: 29500, loss: 0.18
# epoch: 29600, loss: 0.1798
# epoch: 29700, loss: 0.1796
# epoch: 29800, loss: 0.1795
# epoch: 29900, loss: 0.1793
# epoch: 30000, loss: 0.1792
# epoch: 30100, loss: 0.179
# epoch: 30200, loss: 0.1789
# epoch: 30300, loss: 0.1787
# epoch: 30400, loss: 0.1786
# epoch: 30500, loss: 0.1784
# epoch: 30600, loss: 0.1783
# epoch: 30700, loss: 0.1781
# epoch: 30800, loss: 0.178
# epoch: 30900, loss: 0.1778
# epoch: 31000, loss: 0.1777
# epoch: 31100, loss: 0.1775
# epoch: 31200, loss: 0.1774
# epoch: 31300, loss: 0.1772
# epoch: 31400, loss: 0.1771
# epoch: 31500, loss: 0.1769
# epoch: 31600, loss: 0.1768
# epoch: 31700, loss: 0.1767
# epoch: 31800, loss: 0.1765
# epoch: 31900, loss: 0.1764
# epoch: 32000, loss: 0.1762
# epoch: 32100, loss: 0.1761
# epoch: 32200, loss: 0.176
# epoch: 32300, loss: 0.1758
# epoch: 32400, loss: 0.1757
# epoch: 32500, loss: 0.1755
# epoch: 32600, loss: 0.1754
# epoch: 32700, loss: 0.1753
# epoch: 32800, loss: 0.1751
# epoch: 32900, loss: 0.175
# epoch: 33000, loss: 0.1749
# epoch: 33100, loss: 0.1747
# epoch: 33200, loss: 0.1746
# epoch: 33300, loss: 0.1745
# epoch: 33400, loss: 0.1743
# epoch: 33500, loss: 0.1742
# epoch: 33600, loss: 0.1741
# epoch: 33700, loss: 0.1739
# epoch: 33800, loss: 0.1738
# epoch: 33900, loss: 0.1737
# epoch: 34000, loss: 0.1736
# epoch: 34100, loss: 0.1734
# epoch: 34200, loss: 0.1733
# epoch: 34300, loss: 0.1732
# epoch: 34400, loss: 0.173
# epoch: 34500, loss: 0.1729
# epoch: 34600, loss: 0.1728
# epoch: 34700, loss: 0.1727
# epoch: 34800, loss: 0.1725
# epoch: 34900, loss: 0.1724
# epoch: 35000, loss: 0.1723
# epoch: 35100, loss: 0.1722
# epoch: 35200, loss: 0.1721
# epoch: 35300, loss: 0.1719
# epoch: 35400, loss: 0.1718
# epoch: 35500, loss: 0.1717
# epoch: 35600, loss: 0.1716
# epoch: 35700, loss: 0.1714
# epoch: 35800, loss: 0.1713
# epoch: 35900, loss: 0.1712
# epoch: 36000, loss: 0.1711
# epoch: 36100, loss: 0.171
# epoch: 36200, loss: 0.1709
# epoch: 36300, loss: 0.1707
# epoch: 36400, loss: 0.1706
# epoch: 36500, loss: 0.1705
# epoch: 36600, loss: 0.1704
# epoch: 36700, loss: 0.1703
# epoch: 36800, loss: 0.1702
# epoch: 36900, loss: 0.17
# epoch: 37000, loss: 0.1699
# epoch: 37100, loss: 0.1698
# epoch: 37200, loss: 0.1697
# epoch: 37300, loss: 0.1696
# epoch: 37400, loss: 0.1695
# epoch: 37500, loss: 0.1694
# epoch: 37600, loss: 0.1693
# epoch: 37700, loss: 0.1692
# epoch: 37800, loss: 0.169
# epoch: 37900, loss: 0.1689
# epoch: 38000, loss: 0.1688
# epoch: 38100, loss: 0.1687
# epoch: 38200, loss: 0.1686
# epoch: 38300, loss: 0.1685
# epoch: 38400, loss: 0.1684
# epoch: 38500, loss: 0.1683
# epoch: 38600, loss: 0.1682
# epoch: 38700, loss: 0.1681
# epoch: 38800, loss: 0.168
# epoch: 38900, loss: 0.1679
# epoch: 39000, loss: 0.1678
# epoch: 39100, loss: 0.1677
# epoch: 39200, loss: 0.1675
# epoch: 39300, loss: 0.1674
# epoch: 39400, loss: 0.1673
# epoch: 39500, loss: 0.1672
# epoch: 39600, loss: 0.1671
# epoch: 39700, loss: 0.167
# epoch: 39800, loss: 0.1669
# epoch: 39900, loss: 0.1668
# epoch: 40000, loss: 0.1667
# epoch: 40100, loss: 0.1666
# epoch: 40200, loss: 0.1665
# epoch: 40300, loss: 0.1664
# epoch: 40400, loss: 0.1663
# epoch: 40500, loss: 0.1662
# epoch: 40600, loss: 0.1661
# epoch: 40700, loss: 0.166
# epoch: 40800, loss: 0.1659
# epoch: 40900, loss: 0.1658
# epoch: 41000, loss: 0.1657
# epoch: 41100, loss: 0.1656
# epoch: 41200, loss: 0.1655
# epoch: 41300, loss: 0.1655
# epoch: 41400, loss: 0.1654
# epoch: 41500, loss: 0.1653
# epoch: 41600, loss: 0.1652
# epoch: 41700, loss: 0.1651
# epoch: 41800, loss: 0.165
# epoch: 41900, loss: 0.1649
# epoch: 42000, loss: 0.1648
# epoch: 42100, loss: 0.1647
# epoch: 42200, loss: 0.1646
# epoch: 42300, loss: 0.1645
# epoch: 42400, loss: 0.1644
# epoch: 42500, loss: 0.1643
# epoch: 42600, loss: 0.1642
# epoch: 42700, loss: 0.1641
# epoch: 42800, loss: 0.164
# epoch: 42900, loss: 0.164
# epoch: 43000, loss: 0.1639
# epoch: 43100, loss: 0.1638
# epoch: 43200, loss: 0.1637
# epoch: 43300, loss: 0.1636
# epoch: 43400, loss: 0.1635
# epoch: 43500, loss: 0.1634
# epoch: 43600, loss: 0.1633
# epoch: 43700, loss: 0.1632
# epoch: 43800, loss: 0.1632
# epoch: 43900, loss: 0.1631
# epoch: 44000, loss: 0.163
# epoch: 44100, loss: 0.1629
# epoch: 44200, loss: 0.1628
# epoch: 44300, loss: 0.1627
# epoch: 44400, loss: 0.1626
# epoch: 44500, loss: 0.1625
# epoch: 44600, loss: 0.1625
# epoch: 44700, loss: 0.1624
# epoch: 44800, loss: 0.1623
# epoch: 44900, loss: 0.1622
# epoch: 45000, loss: 0.1621
# epoch: 45100, loss: 0.162
# epoch: 45200, loss: 0.162
# epoch: 45300, loss: 0.1619
# epoch: 45400, loss: 0.1618
# epoch: 45500, loss: 0.1617
# epoch: 45600, loss: 0.1616
# epoch: 45700, loss: 0.1615
# epoch: 45800, loss: 0.1615
# epoch: 45900, loss: 0.1614
# epoch: 46000, loss: 0.1613
# epoch: 46100, loss: 0.1612
# epoch: 46200, loss: 0.1611
# epoch: 46300, loss: 0.1611
# epoch: 46400, loss: 0.161
# epoch: 46500, loss: 0.1609
# epoch: 46600, loss: 0.1608
# epoch: 46700, loss: 0.1607
# epoch: 46800, loss: 0.1607
# epoch: 46900, loss: 0.1606
# epoch: 47000, loss: 0.1605
# epoch: 47100, loss: 0.1604
# epoch: 47200, loss: 0.1603
# epoch: 47300, loss: 0.1603
# epoch: 47400, loss: 0.1602
# epoch: 47500, loss: 0.1601
# epoch: 47600, loss: 0.16
# epoch: 47700, loss: 0.1599
# epoch: 47800, loss: 0.1599
# epoch: 47900, loss: 0.1598
# epoch: 48000, loss: 0.1597
# epoch: 48100, loss: 0.1596
# epoch: 48200, loss: 0.1596
# epoch: 48300, loss: 0.1595
# epoch: 48400, loss: 0.1594
# epoch: 48500, loss: 0.1593
# epoch: 48600, loss: 0.1593
# epoch: 48700, loss: 0.1592
# epoch: 48800, loss: 0.1591
# epoch: 48900, loss: 0.159
# epoch: 49000, loss: 0.159
# epoch: 49100, loss: 0.1589
# epoch: 49200, loss: 0.1588
# epoch: 49300, loss: 0.1587
# epoch: 49400, loss: 0.1587
# epoch: 49500, loss: 0.1586
# epoch: 49600, loss: 0.1585
# epoch: 49700, loss: 0.1585
# epoch: 49800, loss: 0.1584
# epoch: 49900, loss: 0.1583
# (array([[5.90152856]]), -9.572418646493698)

# %% [markdown]
# ## Plot the loss through the training

# %%
plt.plot(np.arange(len(loss)), loss)
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.show()

# %% [markdown]
# ## Plot the results

# %%
X_new = np.linspace(0, 3, 1000).reshape(-1, 1)
y_class = model.predict(X_new)                       
y_proba = model.prob_predict(X_new)

#Plot predictions as line of best fit
#plt.plot(X_new, y_proba[:, 1], "g-", label="Iris-Virginica")
plt.plot(X_new, y_class, "g-", label="Iris-Virginica classification")
plt.plot(X_new, y_proba, "b-", label="Prob of Iris-Virginica")
#plt.plot(X_new, y_proba[:, 0], "b--", label="Not Iris-Virginica")

#Plot dataset points
xpoints = X
ypoints = y 
plt.scatter(xpoints, ypoints)

#Axis names:
plt.xlabel('petal_width')
plt.ylabel('virginica')
plt.title('Line of best fit')

#Adding a vertical line to indicate the decision boundary
#plt.vlines([1.54], 0, 1, colors='r') 

plt.legend()
plt.show()

# %% [markdown]
# ## Accuracy on test and training sets

# %%
def accuracy(y, y_hat):
    accuracy = np.sum(y == y_hat) / len(y)
    return accuracy


print("Accuracy on  test: ", accuracy(y_test, y_hat=model.predict(X_test)))
# Out:
# Accuracy on  test:  1.0

# %%
print("Accuracy on  train: ", accuracy(y_train, y_hat=model.predict(X_train)))
# Out:
# Accuracy on  train:  0.9555555555555556

# %% [markdown]
# ## Confusion Matrix
# ### Evaluate model using confusion matrix
# This is basically looking at how well your model did on predictions

# %%
from sklearn import metrics

y_pred = model.predict(X_test)
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[12,  0],
#        [ 0,  3]])

# %% [markdown]
# ### Visualize CFM (confusion matrix) using a heatmap

# %%
import seaborn as sns
import pandas as pd

class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="Blues" ,fmt='g') #another color map for confusion matrix: YlGnBu
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 427.9555555555555, 'Predicted label')

# %% [markdown]
# ### Evaluation metrics Accuracy, Precision, Recall

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0

# %% [markdown]
# # Now, the logistic regrecion with Scikit-Learn
# Example cosidering petal length and width Iris dataset

# %%
#Code from: https://scikit-learn.org/stable/auto_examples/linear_model/plot_iris_logistic.html#sphx-glr-auto-examples-linear-model-plot-iris-logistic-py

import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn import datasets

# import some data to play with
iris = datasets.load_iris()
X = iris.data[:, 2:]  # we only take the last two features.
Y = iris.target

# Create an instance of Logistic Regression Classifier and fit the data.
logreg = LogisticRegression(C=1e5)
logreg.fit(X, Y)

# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5
h = 0.02  # step size in the mesh
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = logreg.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure(1, figsize=(4, 3))
plt.pcolormesh(xx, yy, Z, cmap=plt.cm.Paired)

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, edgecolors="k", cmap=plt.cm.Paired)
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")

plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xticks(())
plt.yticks(())

plt.show()

# %% [markdown]
# ## Confusion Matrix, for the Scikit-Learn example
# ### Evaluate model using confusion matrix
# This is basically looking at how well your model did on predictions

# %%
from sklearn import metrics

y_pred = logreg.predict(X)
cnf_matrix = metrics.confusion_matrix(Y, y_pred)
cnf_matrix
# Out:
# array([[50,  0,  0],
#        [ 0, 47,  3],
#        [ 0,  3, 47]])

# %% [markdown]
# ### Visualize CFM (confusion matrix) using a heatmap

# %%
import seaborn as sns
import pandas as pd

class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="Blues" ,fmt='g') #another color map for confusion matrix: YlGnBu
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 427.9555555555555, 'Predicted label')

# %% [markdown]
# ### Evaluation metrics Accuracy, Precision, Recall

# %%
print("Accuracy:",metrics.accuracy_score(Y, y_pred))
print("Precision:",metrics.precision_score(Y, y_pred, average = 'weighted'))
print("Recall:",metrics.recall_score(Y, y_pred, average = 'weighted'))
# Out:
# Accuracy: 0.96
# Precision: 0.96
# Recall: 0.96
