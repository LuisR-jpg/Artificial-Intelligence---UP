# %% [markdown]
# # Comparison of results
#
# Luis Eduardo Robles Jimenez

# %%
from sklearn.decomposition import PCA
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

# %%
alt = ["1678219224-50-", "1678219224-150-", "1678219224-225-"]
samples, fitness, shForces, shMoments, alphas = [], [], [], [], []
for i, txt in enumerate(alt):
    samples += [np.loadtxt(f"experiments/{txt}Population.txt")]
    fitness += [np.loadtxt(f"experiments/{txt}Fitness.txt")]
    shForces += [np.loadtxt(f"experiments/{txt}ShForces.txt")]
    shMoments += [np.loadtxt(f"experiments/{txt}ShMoments.txt")]
    alphas += [(fitness[i] - shMoments[i])/(shForces[i] - shMoments[i])]

# %%
for i in range(len(alt)):
    plt.scatter(shForces[i], shMoments[i])

# %%
plt.boxplot(alphas)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f8fb5b0f2b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f8fb5b0f850>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f8fb5b0f100>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f8fb5b0fdf0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f8fb5b1e100>,
# ...
#  'means': []}

# %%
for s in range(len(alt)):
    plt.scatter(alphas[s], fitness[s], label = alt)
plt.xlabel("Alpha")
plt.ylabel("Fitness")
# Out:
# Text(0, 0.5, 'Fitness')

# %%
for s in range(len(alt)):
    plt.scatter(alphas[s], shForces[s], label = alt)
    plt.scatter(alphas[s], shMoments[s], label = alt)
plt.xlabel("Alpha")
plt.ylabel("shForces")
# Out:
# Text(0, 0.5, 'shForces')

# %%
for s in range(len(alt)):
    plt.scatter(alphas[s], shMoments[s], label = alt)
plt.xlabel("Alpha")
plt.ylabel("shMoments")
# Out:
# Text(0, 0.5, 'shMoments')
