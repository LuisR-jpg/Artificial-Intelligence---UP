# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('GirlFace.png', 0)
plt.imshow(img, cmap = 'gray')

# %%
plt.imshow(cv2.circle(img, (260, 240), 10, (255, 0, 0), -1), cmap = "gray")
