# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread("../Chair.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(image, cmap="gray")

# %%
t = np.log(abs(np.fft.fftshift(np.fft.fft2(image))))
plt.imshow(t, cmap="gray")
t.shape
# Out:
# (425, 425)
