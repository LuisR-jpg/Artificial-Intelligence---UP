# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
#img = cv2.imread('noisy.png',0)
img = cv2.imread('../noisy_lena.png', 0)
#print("hola", img.shape)

img_float32 = np.float32(img)

dft = cv2.dft(img_float32, flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)

magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))

plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
g = np.array([
    [0, 1, 0],
    [0, 1, 0],
    [0, 1, 0],
])

img_float32 = np.float32(g)

dft = cv2.dft(img_float32, flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)

magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))

plt.subplot(121),plt.imshow(g, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# C:\Users\lalor\AppData\Local\Temp\ipykernel_20392\4170760201.py:12: RuntimeWarning: divide by zero encountered in log
#   magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))

# %%
cZ = cv2.idft(np.float32(np.fft.ifftshift(dft_shift)), flags = cv2.DFT_SCALE)
plt.imshow(cv2.magnitude(cZ[:, :, 0], cZ[:, :, 1]), cmap = "gray")

# %%
m = np.zeros((50,50))
cv2.circle(m, (25,25), 15, (255,255,255), -1)
cv2.circle(m, (25,25), 5, (0,0,0), -1)
m = m.astype(bool)

img_float32 = np.float32(m)

dft = cv2.dft(img_float32, flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)

magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))

plt.subplot(121),plt.imshow(m, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# C:\Users\lalor\AppData\Local\Temp\ipykernel_20392\3615313019.py:11: RuntimeWarning: divide by zero encountered in log
#   magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))

# %%
m = np.zeros((10,10))
m[:, :] = [(np.cos(i/30) + 1)*100 for i in range(m.shape[1])]
#m = m.astype(bool)

img_float32 = np.float32(m)

dft = cv2.dft(img_float32, flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)

magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))
print(np.unique(magnitude_spectrum))

plt.subplot(121),plt.imshow(m, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# [      -inf -346.41797 -340.84656 -336.98065 -336.724   -320.8236
#  -317.87546 -311.20496 -305.61584 -302.61176 -296.60913 -182.96445
#    64.21278   65.22968   68.51817   75.07867   88.84288  197.91159]
# C:\Users\lalor\AppData\Local\Temp\ipykernel_20392\570751995.py:10: RuntimeWarning: divide by zero encountered in log
#   magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))
