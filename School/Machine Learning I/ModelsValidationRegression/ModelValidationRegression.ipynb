# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisR-jpg/School/blob/master/School/Machine%20Learning%20I/ModelsValidationRegression/ModelValidationRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas
import matplotlib.pyplot as plt

# Datasets
from sklearn.datasets import load_diabetes

# Training and testing sets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

# Regression models
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor

# Metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import r2_score
from scipy.stats import pearsonr

# %% [markdown]
# # Datasets

# %%
data = load_diabetes()
print('Feature names:', data.feature_names)
print('Description:', data.DESCR)
# Out:
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Description: .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
# ...

# %%
x, y = load_diabetes(return_X_y = True)
print('X', x.shape)
# Out:
# X (442, 10)

# %%
plt.figure()
plt.subplot(1, 2, 1)
plt.hist(y)
plt.subplot(1, 2, 2)
plt.boxplot(y)
plt.show()

# %% [markdown]
# # Training and testing datasets

# %%
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size = 0.3, random_state = 0)
print('xTrain', xTrain.shape)
print('yTrain', yTrain.shape)
# Out:
# xTrain (309, 10)
# yTrain (309,)

# %% [markdown]
# # Regression Model

# %%
model = LinearRegression()
model.fit(xTrain, yTrain)
yPred = model.predict(xTest)

print('MAE', mean_absolute_error(yTest, yPred))
print('MSE', mean_squared_error(yTest, yPred))
print('R2 score:', r2_score(yTest, yPred))
print('Correlation', pearsonr(yTest, yPred)[0])
print('Mean', np.mean(yTest))
print('STD', np.std(yTest))

plt.figure(figsize = (10, 5))
plt.subplot(1, 2, 1)
plt.scatter(yTest, yPred)
plt.plot([0, 350], [0, 350])
plt.subplot(1, 2, 2)
plt.boxplot([yTest, yPred], labels = ['yTest', 'yPred'])
plt.show()
# Out:
# MAE 44.61794011407202
# MSE 3097.1461383877977
# R2 score: 0.3928939845074757
# Correlation 0.6381614818686364
# Mean 152.1654135338346
# STD 71.4247256582432

# %%
model = RandomForestRegressor()
model.fit(xTrain, yTrain)
yPred = model.predict(xTest)

print('MAE', mean_absolute_error(yTest, yPred))
print('MSE', mean_squared_error(yTest, yPred))
print('R2 score:', r2_score(yTest, yPred))
print('Correlation', pearsonr(yTest, yPred)[0])
print('Mean', np.mean(yTest))
print('STD', np.std(yTest))

plt.figure(figsize = (10, 5))
plt.subplot(1, 2, 1)
plt.scatter(yTest, yPred)
plt.plot([0, 350], [0, 350])
plt.subplot(1, 2, 2)
plt.boxplot([yTest, yPred], labels = ['yTest', 'yPred'])
plt.show()
# Out:
# MAE 47.07654135338346
# MSE 3426.9540796992483
# R2 score: 0.3282446666578457
# Correlation 0.6106269503611622
# Mean 152.1654135338346
# STD 71.4247256582432

# %%
model = MLPRegressor()
model.fit(xTrain, yTrain)
yPred = model.predict(xTest)

print('MAE', mean_absolute_error(yTest, yPred))
print('MSE', mean_squared_error(yTest, yPred))
print('R2 score:', r2_score(yTest, yPred))
print('Correlation', pearsonr(yTest, yPred)[0])
print('Mean', np.mean(yTest))
print('STD', np.std(yTest))

plt.figure(figsize = (10, 5))
plt.subplot(1, 2, 1)
plt.scatter(yTest, yPred)
plt.plot([0, 350], [0, 350])
plt.subplot(1, 2, 2)
plt.boxplot([yTest, yPred], labels = ['yTest', 'yPred'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# MAE 135.90285176401594
# MSE 23355.569286229882
# R2 score: -3.5781845529263787
# Correlation 0.5160669713154992
# Mean 152.1654135338346
# STD 71.4247256582432
